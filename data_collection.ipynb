# %%
import requests
import json

url = "https://opendata.paris.fr/api/explore/v2.1/catalog/datasets/antennes-relais/records?limit=100"


response = requests.get(url)
data = response.json()

print(json.dumps(data, indent=2))
# Out:
# {
#   "total_count": 2170,
#   "results": [
#     {
#       "code_site": "75116_113_01",
#       "adresse": "5 bis Rue massenet",
#       "operateur": "FREE MOBILE",
#       "mise_en_serv": "2019-08-19",
#       "mise_en_serv_4g": "2019-08-23",
#       "mise_en_serv_5g_3500": null,
#       "mise_en_serv_5g_700": null,
#       "type": "3G/4G/5G",
#       "ardt": "75016",
#       "geo_shape": {
#         "type": "Feature",
#         "geometry": {
#           "coordinates": [
#             2.279549734702397,
#             48.85833815460331
#           ],
#           "type": "Point"
#         },
#         "properties": {}
#       },
#       "geo_point_2d": {
#         "lon": 2.279549734702397,
#         "lat": 48.85833815460331
#       }
#     },
#     {
#       "code_site": "75116_124_26",
#       "adresse": "1 Impasse r\u00e9gnier",
#       "operateur": "FREE MOBILE",
#       "mise_en_serv": "2021-07-29",
#       "mise_en_serv_4g": "2021-07-29",
# ...

# %%
records = data["results"]

import pandas as pd  
df = pd.DataFrame(records)
df.head()
# Out:
#       code_site                              adresse    operateur  \
# 0  75116_113_01                   5 bis Rue massenet  FREE MOBILE
# 1  75116_124_26                    1 Impasse régnier  FREE MOBILE
# 2        T15069                      1 Rue verniquet     BOUYGUES
# 3        T15397  10 Avenue franklin delano roosevelt     BOUYGUES
# 4  75105_010_01                       10 Rue jussieu  FREE MOBILE
#
#   mise_en_serv mise_en_serv_4g mise_en_serv_5g_3500 mise_en_serv_5g_700  \
# 0   2019-08-19      2019-08-23                 None                None
# 1   2021-07-29      2021-07-29           2021-08-03                None
# 2   2004-02-19            None                 None                None
# 3   2019-12-11            None                 None                None
# 4   2012-07-05      2013-11-06           2024-07-09                None
#
#        type   ardt                                          geo_shape  \
# ...

# %%
import requests

BASE_URL = "https://opendata.paris.fr/api/explore/v2.1/catalog/datasets/antennes-relais/records"
LIMIT = 100  
offset = 0

all_results = []

while True:
    url = f"{BASE_URL}?limit={LIMIT}&offset={offset}"
    response = requests.get(url)
    data = response.json()

    results = data.get("results", [])

    if not results:
        break

    all_results.extend(results)
    offset += LIMIT

print(f"Total récupéré : {len(all_results)} enregistrements")
# Out:
# Total récupéré : 2170 enregistrements

# %%
import pandas as pd
df = pd.DataFrame(all_results)

# %%
df
# Out:
#          code_site                              adresse    operateur  \
# 0     75116_113_01                   5 bis Rue massenet  FREE MOBILE
# 1     75116_124_26                    1 Impasse régnier  FREE MOBILE
# 2           T15069                      1 Rue verniquet     BOUYGUES
# 3           T15397  10 Avenue franklin delano roosevelt     BOUYGUES
# 4     75105_010_01                       10 Rue jussieu  FREE MOBILE
# ...            ...                                  ...          ...
# 2165    00007556U5             9-11 Place lachambeaudie       ORANGE
# 2166  75114_020_04                   95 Avenue du maine  FREE MOBILE
# 2167  75113_006_10                 95 Rue du chevaleret  FREE MOBILE
# 2168        750057                     97 Rue de crimee          SFR
# 2169    00020533U5             Avenue winston churchill       ORANGE
#
#      mise_en_serv mise_en_serv_4g mise_en_serv_5g_3500 mise_en_serv_5g_700  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2170 entries, 0 to 2169
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   code_site             2170 non-null   object
#  1   adresse               2170 non-null   object
#  2   operateur             2170 non-null   object
#  3   mise_en_serv          2049 non-null   object
#  4   mise_en_serv_4g       1064 non-null   object
#  5   mise_en_serv_5g_3500  788 non-null    object
#  6   mise_en_serv_5g_700   0 non-null      object
#  7   type                  1583 non-null   object
#  8   ardt                  2170 non-null   object
#  9   geo_shape             2170 non-null   object
#  10  geo_point_2d          2170 non-null   object
# dtypes: object(11)
# memory usage: 186.6+ KB

# %%
df.to_csv("antennes.csv", index=False)
